# %%
'''
punto 1. tracciare un grafico per controllare se c'è una relazione tra 
il numero di cilindri e la cilindrata.

punto 2. ispezionando il grafico ottenuto prima, c'è una qualche relazione 
tra il numero di cilindri e la cilindrata dell'auto ?

punto 3. usare il valore di un appropriato indice numerico a supporto 
della vostra risposta al punto precedente
'''

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy.constants import golden 

plt.style.use('fivethirtyeight')
plt.rc('figure', figsize = (5.0, 5.0/golden)) 

cars = pd.read_csv('mtcars2.txt', sep = '\t', index_col = 0, decimal=",", dtype ={
    'consumo':np.float64, 'cilindrata':np.float64, 'test400metri':np.float64
})


cilindri = cars['cilindri']
cilindrata = cars['cilindrata']
levels = np.linspace(0,1,100)

'''punto 1'''
plt.plot([min(cilindri), max(cilindri)], [min(cilindrata), max(cilindrata)])
plt.plot(cilindri.quantile(levels), cilindrata.quantile(levels), 'o')
plt.show()

'''punto 2
il grafico ottenuto precedentemente ci mostra come a bassi valori del 
numero di cilindri corrisponde una bassa cilindrata e viceversa.
'''

'''punto 3'''
for x, y in cilindri, cilindrata
