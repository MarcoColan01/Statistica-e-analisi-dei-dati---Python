# %%
#RIPASSO SU DATI E FREQUENZE CON UN DATASET TROVATO SU KAGGLE RELATIVO ALLE AUTO ELETTRICHE A WASHINGTON

import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

cars = pd.read_csv('dataset_concessionaria.csv', sep = ',', index_col = 0)
cars
# Out:
#            Marca  Modello  Anno  Prezzo   Colore  Chilometraggio  \
# ID
# 1           Audi      RS6  2001   48455     Nero           23420
# 2            BMW    Jetta  2023   31497  Argento           18937
# 3           Audi    Civic  2018   22404    Rosso          147054
# 4           Ford   Altima  2011   31970    Rosso          102946
# 5           Ford    Focus  2000   37060    Rosso           60846
# ...          ...      ...   ...     ...      ...             ...
# 996       Nissan      RS6  2010   46825      Blu           92521
# 997       Nissan  C-Class  2016   33104  Argento           41212
# 998        Honda   Altima  2001   27589    Rosso           14401
# 999   Volkswagen    Civic  2012   48596     Nero           43000
# 1000        Ford  C-Class  2008   10484   Bianco          137059
#
#       Numero_di_Proprietari Trasmissione Motorizzazione  Cavalli  Vel_Max  \
# ID
# 1                         2   Automatico        Benzina      928      304
# ...
