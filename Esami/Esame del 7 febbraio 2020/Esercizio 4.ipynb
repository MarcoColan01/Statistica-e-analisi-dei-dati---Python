# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy.constants import golden 

plt.style.use('fivethirtyeight')
plt.rc('figure', figsize = (5.0, 5.0/golden)) 

cars = pd.read_csv('mtcars2.txt', delimiter = '\t', decimal=",")

cars
# Out:
#                 modello  consumo  cilindrata   peso  test400metri  \
# 0             Mazda RX4     21.0         110  2.620         16.46
# 1         Mazda RX4 Wag     21.0         110  2.875         17.02
# 2            Datsun 710     22.8          93  2.320         18.61
# 3        Hornet 4 Drive     21.4         110  3.215         19.44
# 4     Hornet Sportabout     18.7         175  3.440         17.02
# 5               Valiant     18.1         105  3.460         20.22
# 6            Duster 360     14.3         245  3.570         15.84
# 7             Merc 240D     24.4          62  3.190         20.00
# 8              Merc 230     22.8          95  3.150         22.90
# 9              Merc 280     19.2         123  3.440         18.30
# 10            Merc 280C     17.8         123  3.440         18.90
# 11           Merc 450SE     16.4         180  4.070         17.40
# 12           Merc 450SL     17.3         180  3.730         17.60
# ...

# %%
#4.1 Tracciate un grafico per vedere se c'è una relazione tra numero di cilindri e cilindrata
cars.plot.scatter('cilindri', 'cilindrata')
plt.show()

# %%
#4.2 Ispezionando il grafico di prima, trovate relazione tra numero di cilindir e cilindrata ?
print('si, ad un basso numero di cilindri corrisponde una bassa cilindrata e viceversa')
# Out:
# si, ad un basso numero di cilindri corrisponde una bassa cilindrata e viceversa

# %%
#4.3 Usate il valore di un indice numerico per supportare la vostra risposta di prima
cars['cilindri'].corr(cars['cilindrata'])
# Out:
# 0.8324474527218194
