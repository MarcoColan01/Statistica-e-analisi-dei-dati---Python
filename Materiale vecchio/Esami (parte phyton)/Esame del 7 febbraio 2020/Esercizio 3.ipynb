# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from scipy.constants import golden 

plt.style.use('fivethirtyeight')
plt.rc('figure', figsize = (5.0, 5.0/golden)) 

cars = pd.read_csv('mtcars.txt', delimiter = '\t', decimal=",")

cars

# %%
#3.1 Quanti casi contiene il dataset ?
len(cars)
# Out:
# 32

# %%
#3.2 Tracciate il boxplot di cilindrata
cars.cilindrata.plot.box()
plt.show()

# %%
#3.4 Calcolate i quantili di cilindrata
cars.cilindrata.quantile(0), cars.cilindrata.quantile(0.25), cars.cilindrata.quantile(0.5), cars.cilindrata.quantile(0.75), cars.cilindrata.quantile(1)
# Out:
# (52.0, 96.5, 123.0, 180.0, 335.0)

# %%
#3.5 Tracciate un grafico diverso dal boxplot che rappresenti la distribuzione delle cilindrate
cars.cilindrata.hist()
plt.show()
